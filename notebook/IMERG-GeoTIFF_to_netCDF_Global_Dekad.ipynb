# %% [markdown]
# ## GeoTIFF to netCDF
#
# ---
# Convert IMERG GeoTIFF in a folder to single NetCDF file with time dimension enabled that is CF-Compliant
# http://cfconventions.org/cf-conventions/v1.6.0/cf-conventions.html
#
# Based on Rich Signell's answer on StackExchange: https://gis.stackexchange.com/a/70487
# This script was tested using IMERG dekad data. Adjustment is needed if using other timesteps data for IMERG
# NCO (http://nco.sourceforge.net) must be installed before using this script
#
# Modified by
# Benny Istanto, UN World Food Programme, benny.istanto@wfp.org
#
# ---
#
# ### IMERG Global Dekad

# %%
#!/usr/bin/env python
import numpy as np
import datetime as dt
import os
import gdal
import netCDF4
import re

# %%
ds = gdal.Open('/Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.06.3.tif')

# %%
a = ds.ReadAsArray()
nlat,nlon = np.shape(a)

# %%
b = ds.GetGeoTransform() #bbox, interval
lon = np.arange(nlon)*b[1]+b[0]
lat = np.arange(nlat)*b[5]+b[3]

basedate = dt.datetime(2000,1,1,0,0,0)

# %%
# create NetCDF file
nco = netCDF4.Dataset('wld_cli_imerg_1months_2000_2020_d3.nc','w',clobber=True)

# create dimensions, variables and attributes:
nco.createDimension('lon',nlon)
nco.createDimension('lat',nlat)
nco.createDimension('time',None)

timeo = nco.createVariable('time','f4',('time'))
timeo.units = 'days since 2000-1-1 00:00:00'
timeo.standard_name = 'time'
timeo.calendar = 'gregorian'
timeo.axis = 'T'

lono = nco.createVariable('lon','f4',('lon'))
lono.units = 'degrees_east'
lono.standard_name = 'longitude'
lono.long_name = 'longitude'
lono.axis = 'X'

lato = nco.createVariable('lat','f4',('lat'))
lato.units = 'degrees_north'
lato.standard_name = 'latitude'
lato.long_name = 'latitude'
lato.axis = 'Y'

# create container variable for CRS: lon/lat WGS84 datum
crso = nco.createVariable('crs','i4')
crso.long_name = 'Lon/Lat Coords in WGS84'
crso.grid_mapping_name='latitude_longitude'
crso.longitude_of_prime_meridian = 0.0
crso.semi_major_axis = 6378137.0
crso.inverse_flattening = 298.257223563

# create short integer variable for precipitation data, with chunking
pcpo = nco.createVariable('precip', 'f4',  ('time', 'lat', 'lon'),zlib=True,fill_value=-9999.)
pcpo.units = 'mm'
pcpo.standard_name = 'Precipitation rate'
pcpo.long_name = 'Monthly accumulated precipitation (combined microwave-IR) estimate'
pcpo.time_step = 'month'
pcpo.missing_value = -9999.
pcpo.geospatial_lat_min = -78.
pcpo.geospatial_lat_max = 82.3
pcpo.geospatial_lon_min = -180.
pcpo.geospatial_lon_max = 180.
pcpo.grid_mapping = 'crs'
pcpo.set_auto_maskandscale(False)

nco.Conventions='CF-1.6'
nco.title = "GPM IMERG Precipitation L3 1 month 0.1 degree x 0.1 degree"
nco.history = "The monthly rainfall data originally calculate from dekad, of which the dekad is accumulation of daily rainfall. Calculation process done using Cell Statistics of Spatial Analyst Toolbox in ArcGIS. The objective is to get monthly rainfall with rolling dekad accumulation."
nco.version = "Version 0.6"
nco.comments = "time variable denotes the first day of the given dekad."
nco.website = "https://doi.org/10.5067/GPM/IMERGDF/DAY/06"
nco.date_created = "2021-01-29"
nco.creator_name = "Benny Istanto"
nco.creator_email = "benny.istanto@wfp.org"
nco.institution = "UN World Food Programme"
nco.note = "The data is developed to support regular updating procedure for SPI analysis (https://github.com/wfpidn/SPI). This activities will support WFP to assess extreme dry and wet periods as part of WFP's Seasonal Monitoring"


#write lon,lat
lono[:]=lon
lato[:]=lat

pat = re.compile('wld_cli_imerg-v0.6.[0-9]{4}\.[0-9]{2}\.[0-9]{1}')
itime=0

#step through data, writing time and data to NetCDF
for root, dirs, files in os.walk('/Users/bennyistanto/Temp/IMERG/Dekad/Dekad3'):
    dirs.sort()
    files.sort()
    for f in files:
        if re.match(pat,f):
            # read the time values by parsing the filename
            year=int(f[19:23])
            mon=int(f[24:26])
            dekad=int(f[27:28])
            date=dt.datetime(year,mon,dekad,0,0,0)
            print(date)
            dtime=(date-basedate).total_seconds()/86400.
            timeo[itime]=dtime
           # precipitation
            pcp_path = os.path.join(root,f)
            print(pcp_path)
            pcp=gdal.Open(pcp_path)
            a=pcp.ReadAsArray()  #data
            pcpo[itime,:,:]=a
            itime=itime+1

nco.close()
# Out:
# 2000-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.06.3.tif
# 2000-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.07.3.tif
# 2000-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.08.3.tif
# 2000-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.09.3.tif
# 2000-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.10.3.tif
# 2000-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.11.3.tif
# 2000-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2000.12.3.tif
# 2001-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.01.3.tif
# 2001-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.02.3.tif
# 2001-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.03.3.tif
# 2001-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.04.3.tif
# 2001-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.05.3.tif
# 2001-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.06.3.tif
# 2001-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.07.3.tif
# 2001-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.08.3.tif
# 2001-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.09.3.tif
# 2001-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.10.3.tif
# 2001-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.11.3.tif
# 2001-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2001.12.3.tif
# 2002-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.01.3.tif
# 2002-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.02.3.tif
# 2002-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.03.3.tif
# 2002-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.04.3.tif
# 2002-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.05.3.tif
# 2002-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.06.3.tif
# 2002-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.07.3.tif
# 2002-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.08.3.tif
# 2002-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.09.3.tif
# 2002-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.10.3.tif
# 2002-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.11.3.tif
# 2002-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2002.12.3.tif
# 2003-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.01.3.tif
# 2003-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.02.3.tif
# 2003-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.03.3.tif
# 2003-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.04.3.tif
# 2003-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.05.3.tif
# 2003-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.06.3.tif
# 2003-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.07.3.tif
# 2003-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.08.3.tif
# 2003-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.09.3.tif
# 2003-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.10.3.tif
# 2003-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.11.3.tif
# 2003-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2003.12.3.tif
# 2004-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.01.3.tif
# 2004-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.02.3.tif
# 2004-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.03.3.tif
# 2004-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.04.3.tif
# 2004-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.05.3.tif
# 2004-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.06.3.tif
# 2004-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.07.3.tif
# 2004-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.08.3.tif
# 2004-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.09.3.tif
# 2004-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.10.3.tif
# 2004-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.11.3.tif
# 2004-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2004.12.3.tif
# 2005-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.01.3.tif
# 2005-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.02.3.tif
# 2005-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.03.3.tif
# 2005-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.04.3.tif
# 2005-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.05.3.tif
# 2005-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.06.3.tif
# 2005-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.07.3.tif
# 2005-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.08.3.tif
# 2005-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.09.3.tif
# 2005-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.10.3.tif
# 2005-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.11.3.tif
# 2005-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2005.12.3.tif
# 2006-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.01.3.tif
# 2006-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.02.3.tif
# 2006-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.03.3.tif
# 2006-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.04.3.tif
# 2006-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.05.3.tif
# 2006-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.06.3.tif
# 2006-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.07.3.tif
# 2006-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.08.3.tif
# 2006-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.09.3.tif
# 2006-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.10.3.tif
# 2006-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.11.3.tif
# 2006-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2006.12.3.tif
# 2007-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.01.3.tif
# 2007-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.02.3.tif
# 2007-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.03.3.tif
# 2007-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.04.3.tif
# 2007-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.05.3.tif
# 2007-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.06.3.tif
# 2007-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.07.3.tif
# 2007-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.08.3.tif
# 2007-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.09.3.tif
# 2007-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.10.3.tif
# 2007-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.11.3.tif
# 2007-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2007.12.3.tif
# 2008-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.01.3.tif
# 2008-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.02.3.tif
# 2008-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.03.3.tif
# 2008-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.04.3.tif
# 2008-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.05.3.tif
# 2008-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.06.3.tif
# 2008-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.07.3.tif
# 2008-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.08.3.tif
# 2008-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.09.3.tif
# 2008-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.10.3.tif
# 2008-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.11.3.tif
# 2008-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2008.12.3.tif
# 2009-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.01.3.tif
# 2009-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.02.3.tif
# 2009-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.03.3.tif
# 2009-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.04.3.tif
# 2009-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.05.3.tif
# 2009-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.06.3.tif
# 2009-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.07.3.tif
# 2009-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.08.3.tif
# 2009-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.09.3.tif
# 2009-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.10.3.tif
# 2009-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.11.3.tif
# 2009-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2009.12.3.tif
# 2010-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.01.3.tif
# 2010-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.02.3.tif
# 2010-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.03.3.tif
# 2010-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.04.3.tif
# 2010-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.05.3.tif
# 2010-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.06.3.tif
# 2010-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.07.3.tif
# 2010-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.08.3.tif
# 2010-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.09.3.tif
# 2010-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.10.3.tif
# 2010-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.11.3.tif
# 2010-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2010.12.3.tif
# 2011-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.01.3.tif
# 2011-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.02.3.tif
# 2011-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.03.3.tif
# 2011-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.04.3.tif
# 2011-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.05.3.tif
# 2011-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.06.3.tif
# 2011-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.07.3.tif
# 2011-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.08.3.tif
# 2011-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.09.3.tif
# 2011-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.10.3.tif
# 2011-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.11.3.tif
# 2011-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2011.12.3.tif
# 2012-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.01.3.tif
# 2012-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.02.3.tif
# 2012-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.03.3.tif
# 2012-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.04.3.tif
# 2012-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.05.3.tif
# 2012-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.06.3.tif
# 2012-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.07.3.tif
# 2012-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.08.3.tif
# 2012-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.09.3.tif
# 2012-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.10.3.tif
# 2012-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.11.3.tif
# 2012-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2012.12.3.tif
# 2013-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.01.3.tif
# 2013-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.02.3.tif
# 2013-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.03.3.tif
# 2013-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.04.3.tif
# 2013-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.05.3.tif
# 2013-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.06.3.tif
# 2013-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.07.3.tif
# 2013-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.08.3.tif
# 2013-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.09.3.tif
# 2013-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.10.3.tif
# 2013-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.11.3.tif
# 2013-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2013.12.3.tif
# 2014-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.01.3.tif
# 2014-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.02.3.tif
# 2014-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.03.3.tif
# 2014-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.04.3.tif
# 2014-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.05.3.tif
# 2014-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.06.3.tif
# 2014-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.07.3.tif
# 2014-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.08.3.tif
# 2014-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.09.3.tif
# 2014-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.10.3.tif
# 2014-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.11.3.tif
# 2014-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2014.12.3.tif
# 2015-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.01.3.tif
# 2015-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.02.3.tif
# 2015-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.03.3.tif
# 2015-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.04.3.tif
# 2015-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.05.3.tif
# 2015-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.06.3.tif
# 2015-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.07.3.tif
# 2015-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.08.3.tif
# 2015-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.09.3.tif
# 2015-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.10.3.tif
# 2015-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.11.3.tif
# 2015-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2015.12.3.tif
# 2016-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.01.3.tif
# 2016-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.02.3.tif
# 2016-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.03.3.tif
# 2016-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.04.3.tif
# 2016-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.05.3.tif
# 2016-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.06.3.tif
# 2016-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.07.3.tif
# 2016-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.08.3.tif
# 2016-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.09.3.tif
# 2016-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.10.3.tif
# 2016-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.11.3.tif
# 2016-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2016.12.3.tif
# 2017-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.01.3.tif
# 2017-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.02.3.tif
# 2017-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.03.3.tif
# 2017-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.04.3.tif
# 2017-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.05.3.tif
# 2017-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.06.3.tif
# 2017-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.07.3.tif
# 2017-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.08.3.tif
# 2017-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.09.3.tif
# 2017-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.10.3.tif
# 2017-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.11.3.tif
# 2017-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2017.12.3.tif
# 2018-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.01.3.tif
# 2018-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.02.3.tif
# 2018-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.03.3.tif
# 2018-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.04.3.tif
# 2018-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.05.3.tif
# 2018-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.06.3.tif
# 2018-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.07.3.tif
# 2018-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.08.3.tif
# 2018-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.09.3.tif
# 2018-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.10.3.tif
# 2018-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.11.3.tif
# 2018-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2018.12.3.tif
# 2019-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.01.3.tif
# 2019-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.02.3.tif
# 2019-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.03.3.tif
# 2019-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.04.3.tif
# 2019-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.05.3.tif
# 2019-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.06.3.tif
# 2019-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.07.3.tif
# 2019-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.08.3.tif
# 2019-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.09.3.tif
# 2019-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.10.3.tif
# 2019-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.11.3.tif
# 2019-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2019.12.3.tif
# 2020-01-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.01.3.tif
# 2020-02-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.02.3.tif
# 2020-03-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.03.3.tif
# 2020-04-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.04.3.tif
# 2020-05-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.05.3.tif
# 2020-06-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.06.3.tif
# 2020-07-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.07.3.tif
# 2020-08-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.08.3.tif
# 2020-09-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.09.3.tif
# 2020-10-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.10.3.tif
# 2020-11-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.11.3.tif
# 2020-12-03 00:00:00
# /Users/bennyistanto/Temp/IMERG/Dekad/Dekad3/wld_cli_imerg-v0.6.2020.12.3.tif
